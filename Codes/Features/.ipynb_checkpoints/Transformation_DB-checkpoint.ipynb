# %%
import os
import pandas as pd
import json

# %%
def extract_species(x):
    try:
        parts = x.split('_')
        return "_".join(parts[:2])
    except IndexError:
        return None

# %%
# Chemins des données
base_path = "./birds_dataset"
features_file = "./second_birds_combined_features.csv"

# Charger le fichier des features des oiseaux
try:
    birds_features = pd.read_csv(features_file)
    if "image_name" not in birds_features.columns:
        raise KeyError("La colonne 'image_name' est absente dans second_birds_combined_features.csv.")
    print("Fichier des features chargé avec succès.")
except Exception as e:
    print(f"Erreur lors du chargement du fichier des features: {e}")
    exit()
# Out:
# Fichier des features chargé avec succès.

# %%
# Ajuster 'image_name' pour correspondre au format des dossiers dans birds_dataset
# Garder seulement jusqu'au deuxième underscore pour correspondre à `species`
birds_features["species"] = birds_features["image_name"].apply(extract_species)
birds_features["species"] = birds_features["species"].str.strip()  # Enlever les espaces au début/fin
birds_features["species"]
# Out:
# 0      Nycticorax_nycticorax
# 1        Nannopterum_auritum
# 2             Cathartes_aura
# 3        Dryobates_pubescens
# 4        Meleagris_gallopavo
#                ...
# 320     Haemorhous_mexicanus
# 321         Fulica_americana
# 322              Cygnus_olor
# 323        Mimus_polyglottos
# 324      Agelaius_phoeniceus
# Name: species, Length: 325, dtype: object

# %%
# Initialiser une liste pour stocker les données combinées
combined_data = []

# Parcourir les dossiers par espèce
species_list = [
    os.path.join(base_path, species)
    for species in os.listdir(base_path)
    if os.path.isdir(os.path.join(base_path, species))
]

print("Liste des espèces :", species_list)

for species_dir in species_list:
    species_name = os.path.basename(species_dir)

    # Lire les fichiers climate_data et coordinates
    climate_data_path = os.path.join(species_dir, "climate_data.txt")
    coordinates_path = os.path.join(species_dir, "coordinates.txt")

    try:
        # Lire les données climatiques
        with open(climate_data_path, "r") as f:
            climate_lines = f.readlines()
        
        # Séparer les colonnes manuellement
        climate_data = pd.DataFrame([line.strip().split(", ") for line in climate_lines], 
                                    columns=["climate_var1", "climate_var2", "climate_var3"])

        # Lire les données de coordonnées
        with open(coordinates_path, "r") as f:
            coord_lines = f.readlines()
        
        # Nettoyer les coordonnées : retirer "Coordinates:" et séparer latitude/longitude
        coordinates_cleaned = pd.DataFrame(
            [line.strip().replace("Coordinates: ", "").split(", ") for line in coord_lines], 
            columns=["latitude", "longitude"]
        )
        
        # Convertir latitude et longitude en float
        coordinates_cleaned["latitude"] = coordinates_cleaned["latitude"].astype(float)
        coordinates_cleaned["longitude"] = coordinates_cleaned["longitude"].astype(float)

        # Vérifier que les deux fichiers ont le même nombre de lignes
        if len(climate_data) == len(coordinates_cleaned):
            # Générer les noms des images
            image_names = [f"{species_name}_{i+1}" for i in range(len(climate_data))]

            # Créer un DataFrame temporaire combiné
            temp_data = pd.concat([pd.Series(image_names, name="image_name"), climate_data, coordinates_cleaned], axis=1)

            # Ajouter une colonne pour l'espèce
            temp_data["species"] = species_name

            # Réorganiser les colonnes : species et image_name en premier
            temp_data = temp_data[["species", "image_name", "climate_var1", "climate_var2", "climate_var3", "latitude", "longitude"]]

            # Ajouter le DataFrame temporaire à la liste
            combined_data.append(temp_data)
        else:
            print(f"Les fichiers climate_data et coordinates dans {species_dir} n'ont pas le même nombre de lignes.")
    except Exception as e:
        print(f"Erreur lors de la lecture des fichiers dans {species_dir}: {e}")

# Combiner toutes les données dans un seul DataFrame
if combined_data:
    final_climate_coordinates_data = pd.concat(combined_data, ignore_index=True)
    print("Données combinées avec succès.")
else:
    print("Aucune donnée combinée n'a été générée.")
cols = ['species', 'image_name'] + [col for col in birds_features.columns if col not in ['species', 'image_name']]
birds_features = birds_features[cols]
birds_features["image_name"] = birds_features["image_name"].apply(lambda x: "_".join(x.split("_")[:3]))
birds_features.to_csv("birds_features.csv")
# Afficher un aperçu des données combinées
final_climate_coordinates_data.to_csv("climate_coordinates_data.csv")
# Out:
# Liste des espèces : ['./birds_dataset\\Agelaius_phoeniceus', './birds_dataset\\Anas_platyrhynchos', './birds_dataset\\Ardea_alba', './birds_dataset\\Ardea_cinerea', './birds_dataset\\Ardea_herodias', './birds_dataset\\Astur_cooperii', './birds_dataset\\Branta_canadensis', './birds_dataset\\Buteo_jamaicensis', './birds_dataset\\Buteo_lineatus', './birds_dataset\\Cardinalis_cardinalis', './birds_dataset\\Cathartes_aura', './birds_dataset\\Charadrius_vociferus', './birds_dataset\\Chroicocephalus_ridibundus', './birds_dataset\\Colaptes_auratus', './birds_dataset\\Columba_livia', './birds_dataset\\Corvus_brachyrhynchos', './birds_dataset\\Corvus_corax', './birds_dataset\\Cyanocitta_cristata', './birds_dataset\\Cygnus_olor', './birds_dataset\\Dryobates_pubescens', './birds_dataset\\Egretta_thula', './birds_dataset\\Erithacus_rubecula', './birds_dataset\\Fringilla_coelebs', './birds_dataset\\Fulica_americana', './birds_dataset\\Fulica_atra', './birds_dataset\\Haemorhous_mexicanus', './birds_dataset\\Haliaeetus_leucocephalus', './birds_dataset\\Hirundo_rustica', './birds_dataset\\Junco_hyemalis', './birds_dataset\\Larus_delawarensis', './birds_dataset\\Meleagris_gallopavo', './birds_dataset\\Melospiza_melodia', './birds_dataset\\Mimus_polyglottos', './birds_dataset\\Motacilla_alba', './birds_dataset\\Nannopterum_auritum', './birds_dataset\\Nycticorax_nycticorax', './birds_dataset\\Pandion_haliaetus', './birds_dataset\\Parus_major', './birds_dataset\\Passer_domesticus', './birds_dataset\\Poecile_atricapillus', './birds_dataset\\Quiscalus_mexicanus', './birds_dataset\\Setophaga_coronata', './birds_dataset\\Sialia_sialis', './birds_dataset\\Spinus_tristis', './birds_dataset\\Streptopelia_decaocto', './birds_dataset\\Sturnus_vulgaris', './birds_dataset\\Turdus_merula', './birds_dataset\\Turdus_migratorius', './birds_dataset\\Zenaida_macroura', './birds_dataset\\Zonotrichia_leucophrys']
# Données combinées avec succès.

# %%
birds_features
# Out:
#                    species               image_name  feature_0  feature_1  \
# 0    Nycticorax_nycticorax  Nycticorax_nycticorax_5   0.139346   0.000000
# 1      Nannopterum_auritum    Nannopterum_auritum_3   0.097628   0.000000
# 2           Cathartes_aura         Cathartes_aura_3   0.063757   0.002176
# 3      Dryobates_pubescens    Dryobates_pubescens_1   0.156524   0.002887
# 4      Meleagris_gallopavo    Meleagris_gallopavo_4   0.227439   0.026346
# ..                     ...                      ...        ...        ...
# 320   Haemorhous_mexicanus   Haemorhous_mexicanus_2   0.000000   0.000000
# 321       Fulica_americana       Fulica_americana_1   0.126797   0.096359
# 322            Cygnus_olor            Cygnus_olor_4   0.051752   0.012972
# 323      Mimus_polyglottos      Mimus_polyglottos_1   0.040863   0.000000
# 324    Agelaius_phoeniceus    Agelaius_phoeniceus_1   0.158221   0.085771
#
#      feature_2  feature_3  feature_4  feature_5  feature_6  feature_7  ...  \
# 0     0.068517   0.020429   0.163285   0.216670   0.154884   0.102822  ...
# 1     0.027504   0.015246   0.252503   0.211766   0.234390   0.063763  ...
# 2     0.189566   0.337707   0.228905   0.009978   0.008488   0.005604  ...
# 3     0.284261   0.117919   0.284261   0.133698   0.009143   0.009870  ...
# 4     0.190284   0.145307   0.219196   0.171729   0.227439   0.209838  ...
# ..         ...        ...        ...        ...        ...        ...  ...
# 320   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000  ...
# 321   0.142161   0.165873   0.259298   0.079942   0.075038   0.011935  ...
# 322   0.020030   0.007922   0.040861   0.019806   0.027099   0.003955  ...
# 323   0.008666   0.000000   0.014319   0.000000   0.014444   0.000000  ...
# 324   0.051971   0.027295   0.239087   0.239087   0.191282   0.142309  ...
#
#      feature_24293  feature_24294  feature_24295  feature_24296  \
# 0         0.268899       0.076876       0.268899       0.250486
# 1         0.176530       0.074186       0.180702       0.245440
# 2         0.119392       0.270285       0.270285       0.061064
# 3         0.100816       0.021444       0.200168       0.249502
# 4         0.049702       0.093389       0.233785       0.233785
# ..             ...            ...            ...            ...
# 320       0.017243       0.061404       0.305866       0.208094
# 321       0.174326       0.236529       0.236529       0.146415
# 322       0.021501       0.041607       0.151985       0.097789
# 323       0.089755       0.121202       0.155438       0.031507
# 324       0.327486       0.235492       0.240610       0.014674
#
#      feature_24297  feature_24298  feature_24299  feature_24300  \
# 0         0.042583       0.089110       0.060802      85.704041
# 1         0.245440       0.097022       0.076249      97.498352
# 2         0.013641       0.028015       0.000000      67.046875
# 3         0.210926       0.028388       0.035827      85.657227
# 4         0.177662       0.131284       0.026807      79.885010
# ..             ...            ...            ...            ...
# 320       0.198388       0.048944       0.113238      89.685913
# 321       0.020543       0.089619       0.030665      73.147644
# 322       0.046595       0.060733       0.032268      78.183289
# 323       0.046525       0.032192       0.044468      57.196106
# 324       0.088998       0.028711       0.017885      67.455872
#
#      feature_24301  feature_24302
# 0        60.676086     120.936646
# 1        27.115417      93.024353
# 2        30.084351     125.654846
# 3        80.006409     116.632629
# 4        51.020020     112.676697
# ..             ...            ...
# 320      79.422302     184.909363
# 321      42.568115      93.918213
# 322      43.053101     141.508484
# 323     118.555115     178.345459
# 324      79.798828      62.913635
#
# [325 rows x 24305 columns]

# %%
final_climate_coordinates_data
# Out:
#                     species                image_name climate_var1  \
# 0       Agelaius_phoeniceus     Agelaius_phoeniceus_1    Temperate
# 1       Agelaius_phoeniceus     Agelaius_phoeniceus_2    Temperate
# 2       Agelaius_phoeniceus     Agelaius_phoeniceus_3    Temperate
# 3       Agelaius_phoeniceus     Agelaius_phoeniceus_4    Temperate
# 4       Agelaius_phoeniceus     Agelaius_phoeniceus_5         Arid
# ..                      ...                       ...          ...
# 245  Zonotrichia_leucophrys  Zonotrichia_leucophrys_1         Arid
# 246  Zonotrichia_leucophrys  Zonotrichia_leucophrys_2         Arid
# 247  Zonotrichia_leucophrys  Zonotrichia_leucophrys_3    Temperate
# 248  Zonotrichia_leucophrys  Zonotrichia_leucophrys_4    Temperate
# 249  Zonotrichia_leucophrys  Zonotrichia_leucophrys_5    Temperate
#
#     climate_var2        climate_var3   latitude   longitude
# 0     Hot summer  Without dry season  28.502620  -96.832282
# 1     Hot summer  Without dry season  37.543658  -77.536247
# 2     Hot summer  Without dry season  33.000300  -96.741312
# 3     Hot summer          Dry summer  39.323005 -121.837858
# 4         Steppe                Cold  34.979850 -106.671928
# ..           ...                 ...        ...         ...
# 245       Steppe                Cold  31.399529 -102.020236
# 246       Steppe                Cold  31.399500 -102.020676
# 247   Hot summer          Dry summer  39.187159 -122.056623
# 248   Hot summer          Dry summer  33.799701 -117.757061
# 249   Hot summer          Dry summer  33.709749 -118.058785
#
# [250 rows x 7 columns]

# %% [markdown]
# # Données csv en geojson

# %% [markdown]
# ## birds_data

# %%
# Charger les données depuis le CSV
csv_file = "./climate_coordinates_data.csv"  # Remplace avec le bon chemin
df = pd.read_csv(csv_file)

# Vérifier si les colonnes nécessaires existent
required_columns = {"latitude", "longitude", "species"}
if not required_columns.issubset(df.columns):
    raise ValueError(f"Le fichier CSV doit contenir les colonnes {required_columns}")

# Construire le GeoJSON
geojson_data = {
    "type": "FeatureCollection",
    "features": []
}

for _, row in df.iterrows():
    feature = {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [row["longitude"], row["latitude"]]
        },
        "properties": {
            "species": row["species"],
            "climate_var1": row.get("climate_var1", None),
            "climate_var2": row.get("climate_var2", None),
            "climate_var3": row.get("climate_var3", None),
        }
    }
    geojson_data["features"].append(feature)

# Sauvegarde en fichier GeoJSON
geojson_file = "birds_data.geojson"
with open(geojson_file, "w") as f:
    json.dump(geojson_data, f, indent=4)

print(f"GeoJSON sauvegardé sous {geojson_file}")
# Out:
# GeoJSON sauvegardé sous birds_data.geojson

# %%
geojson_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8322818113, 28.5026198445]},
#    'properties': {'species': 'Agelaius_phoeniceus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.5362466667, 37.5436583333]},
#    'properties': {'species': 'Agelaius_phoeniceus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-96.7413116667, 33.0003]},
#    'properties': {'species': 'Agelaius_phoeniceus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.8378583586, 39.3230053652]},
#    'properties': {'species': 'Agelaius_phoeniceus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-106.6719283333, 34.97985]},
#    'properties': {'species': 'Agelaius_phoeniceus',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [103.8731305556, 33.13445]},
#    'properties': {'species': 'Anas_platyrhynchos',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0691199722, 38.8973799722]},
#    'properties': {'species': 'Anas_platyrhynchos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.5111, 38.1388555]},
#    'properties': {'species': 'Anas_platyrhynchos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.058835, 39.187603]},
#    'properties': {'species': 'Anas_platyrhynchos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.047267, 39.188212]},
#    'properties': {'species': 'Anas_platyrhynchos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.3402564181, 27.8628335418]},
#    'properties': {'species': 'Ardea_alba',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.3284938748, 27.8662394503]},
#    'properties': {'species': 'Ardea_alba',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [4.450489, 50.4499139722]},
#    'properties': {'species': 'Ardea_alba',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-16.4145538956, 13.8837064357]},
#    'properties': {'species': 'Ardea_alba',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Hot'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.3094233642, 27.8737387378]},
#    'properties': {'species': 'Ardea_alba',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [103.724208481, 1.4452504985]},
#    'properties': {'species': 'Ardea_cinerea',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Rainforest',
#     'climate_var3': nan}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-16.4205140993, 13.8873736006]},
#    'properties': {'species': 'Ardea_cinerea',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Hot'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [76.6280044444, 12.3075508333]},
#    'properties': {'species': 'Ardea_cinerea',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [100.3330629, 6.1975109]},
#    'properties': {'species': 'Ardea_cinerea',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Monsoon',
#     'climate_var3': nan}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [121.5455827446, 23.8966193823]},
#    'properties': {'species': 'Ardea_cinerea',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.3345298238, 27.8638261499]},
#    'properties': {'species': 'Ardea_herodias',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.0794861318, 27.8271317812]},
#    'properties': {'species': 'Ardea_herodias',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-89.8873289222, 42.9106442993]},
#    'properties': {'species': 'Ardea_herodias',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-81.4378092, 30.4398902]},
#    'properties': {'species': 'Ardea_herodias',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.059263, 39.185037]},
#    'properties': {'species': 'Ardea_herodias',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9241781432, 40.7641604503]},
#    'properties': {'species': 'Astur_cooperii',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.1647658222, 42.2915687141]},
#    'properties': {'species': 'Astur_cooperii',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.0165472167, 42.7983966667]},
#    'properties': {'species': 'Astur_cooperii',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-87.8071216667, 41.9820416667]},
#    'properties': {'species': 'Astur_cooperii',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-73.784005, 40.6774966667]},
#    'properties': {'species': 'Astur_cooperii',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0837028333, 39.0329083333]},
#    'properties': {'species': 'Branta_canadensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.5836661751, 37.3855739457]},
#    'properties': {'species': 'Branta_canadensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.1535920941, 51.5240716952]},
#    'properties': {'species': 'Branta_canadensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.1538353686, 51.5243476405]},
#    'properties': {'species': 'Branta_canadensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1066022713, 38.9506724658]},
#    'properties': {'species': 'Branta_canadensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-74.4435249269, 40.8511001477]},
#    'properties': {'species': 'Buteo_jamaicensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.8941714015, 39.9575774854]},
#    'properties': {'species': 'Buteo_jamaicensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.1456146111, 35.0681648056]},
#    'properties': {'species': 'Buteo_jamaicensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-84.5117716667, 38.1391666667]},
#    'properties': {'species': 'Buteo_jamaicensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-101.9900339489, 31.9840195948]},
#    'properties': {'species': 'Buteo_jamaicensis',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-77.1910869722, 38.953867]},
#    'properties': {'species': 'Buteo_lineatus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.6061777778, 26.3764138889]},
#    'properties': {'species': 'Buteo_lineatus',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-82.326591, 29.682529]},
#    'properties': {'species': 'Buteo_lineatus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-82.4049377441, 27.310213089]},
#    'properties': {'species': 'Buteo_lineatus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-86.9313583333, 34.4315116667]},
#    'properties': {'species': 'Buteo_lineatus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-73.821275, 41.1602388333]},
#    'properties': {'species': 'Cardinalis_cardinalis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.824258177, 32.9889583445]},
#    'properties': {'species': 'Cardinalis_cardinalis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-102.1896275671, 31.4073771328]},
#    'properties': {'species': 'Cardinalis_cardinalis',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.9840434082, 28.1334014525]},
#    'properties': {'species': 'Cardinalis_cardinalis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-88.5595195398, 30.3625289453]},
#    'properties': {'species': 'Cardinalis_cardinalis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.0862564675, 11.4327974408]},
#    'properties': {'species': 'Cathartes_aura',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-89.3311361111, 43.0880472222]},
#    'properties': {'species': 'Cathartes_aura',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.320226, 37.591188]},
#    'properties': {'species': 'Cathartes_aura',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-84.1344937031, 39.0195487894]},
#    'properties': {'species': 'Cathartes_aura',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-84.1307611667, 35.3663633333]},
#    'properties': {'species': 'Cathartes_aura',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8324407636, 28.5027050596]},
#    'properties': {'species': 'Charadrius_vociferus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-106.4623561689, 31.7570225662]},
#    'properties': {'species': 'Charadrius_vociferus',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Desert',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-106.461106157, 31.7584824842]},
#    'properties': {'species': 'Charadrius_vociferus',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Desert',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-106.4627135038, 31.7569920241]},
#    'properties': {'species': 'Charadrius_vociferus',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Desert',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-106.4544698006, 31.7548806098]},
#    'properties': {'species': 'Charadrius_vociferus',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Desert',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.1844545901, 51.5062866211]},
#    'properties': {'species': 'Chroicocephalus_ridibundus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-6.213177, 53.634636]},
#    'properties': {'species': 'Chroicocephalus_ridibundus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.8173171878, 40.7251577443]},
#    'properties': {'species': 'Chroicocephalus_ridibundus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [26.1138725281, 44.4575538635]},
#    'properties': {'species': 'Chroicocephalus_ridibundus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [26.1138458252, 44.4578361511]},
#    'properties': {'species': 'Chroicocephalus_ridibundus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-110.9876522378, 32.2028332975]},
#    'properties': {'species': 'Colaptes_auratus',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Hot'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.823037462, 32.9895180971]},
#    'properties': {'species': 'Colaptes_auratus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.2502871136, 26.73023755]},
#    'properties': {'species': 'Colaptes_auratus',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Rainforest',
#     'climate_var3': nan}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0825068589, 38.5629689445]},
#    'properties': {'species': 'Colaptes_auratus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-70.5527355034, 46.9843651195]},
#    'properties': {'species': 'Colaptes_auratus',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-6.2926888466, 36.5299453735]},
#    'properties': {'species': 'Columba_livia',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [49.1473184153, 55.7870853146]},
#    'properties': {'species': 'Columba_livia',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-72.9428120642, -41.4694524183]},
#    'properties': {'species': 'Columba_livia',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [75.5672893084, 20.9871701057]},
#    'properties': {'species': 'Columba_livia',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-87.584714, 37.9782666]},
#    'properties': {'species': 'Columba_livia',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-87.6096356, 37.9791458]},
#    'properties': {'species': 'Corvus_brachyrhynchos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.0947333333, 36.0805555]},
#    'properties': {'species': 'Corvus_brachyrhynchos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.609445, 25.3823216667]},
#    'properties': {'species': 'Corvus_brachyrhynchos',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-69.8636428921, 47.5679370219]},
#    'properties': {'species': 'Corvus_brachyrhynchos',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-82.8846330455, 35.5829020925]},
#    'properties': {'species': 'Corvus_brachyrhynchos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [30.2566648275, 59.9769466103]},
#    'properties': {'species': 'Corvus_corax',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-102.0299119509, 31.4963417567]},
#    'properties': {'species': 'Corvus_corax',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.833694, 33.767551]},
#    'properties': {'species': 'Corvus_corax',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Hot'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-111.6212278605, 35.1992987928]},
#    'properties': {'species': 'Corvus_corax',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-72.4513680957, 44.31967073]},
#    'properties': {'species': 'Corvus_corax',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-69.7068126331, 47.4720409514]},
#    'properties': {'species': 'Cyanocitta_cristata',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.3640460668, 37.375249642]},
#    'properties': {'species': 'Cyanocitta_cristata',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-95.7655343, 29.8066414]},
#    'properties': {'species': 'Cyanocitta_cristata',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-73.4374973, 45.6810341]},
#    'properties': {'species': 'Cyanocitta_cristata',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-73.4364097, 45.5913698]},
#    'properties': {'species': 'Cyanocitta_cristata',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.0664445683, 51.4166069031]},
#    'properties': {'species': 'Cygnus_olor',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [22.6234663589, 53.4773536778]},
#    'properties': {'species': 'Cygnus_olor',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [26.0295671, 40.8085172]},
#    'properties': {'species': 'Cygnus_olor',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [10.3857510164, 53.3438531682]},
#    'properties': {'species': 'Cygnus_olor',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.1585583333, 51.5253983333]},
#    'properties': {'species': 'Cygnus_olor',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.9871532503, 39.9192698002]},
#    'properties': {'species': 'Dryobates_pubescens',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.5760578415, 39.0110829473]},
#    'properties': {'species': 'Dryobates_pubescens',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0508219722, 38.8967629722]},
#    'properties': {'species': 'Dryobates_pubescens',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.7643457197, 33.1083904244]},
#    'properties': {'species': 'Dryobates_pubescens',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-76.0763388333, 45.480055]},
#    'properties': {'species': 'Dryobates_pubescens',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-81.4378092, 30.4398902]},
#    'properties': {'species': 'Egretta_thula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8036488138, 28.3027432163]},
#    'properties': {'species': 'Egretta_thula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8324744731, 28.5026271552]},
#    'properties': {'species': 'Egretta_thula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-82.8295883333, 27.9722916667]},
#    'properties': {'species': 'Egretta_thula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-81.8263755, 26.2690966]},
#    'properties': {'species': 'Egretta_thula',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [15.2927866667, 37.8523783426]},
#    'properties': {'species': 'Erithacus_rubecula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [2.1054167, 41.4996269997]},
#    'properties': {'species': 'Erithacus_rubecula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.5540112311, 52.5622826765]},
#    'properties': {'species': 'Erithacus_rubecula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-0.2416485, 54.0613949]},
#    'properties': {'species': 'Erithacus_rubecula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-7.7374958035, 41.495309921]},
#    'properties': {'species': 'Erithacus_rubecula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [15.6687573776, 47.1215915993]},
#    'properties': {'species': 'Fringilla_coelebs',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.0513643026, 39.9274710829]},
#    'properties': {'species': 'Fringilla_coelebs',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [11.5729611111, 46.4083944444]},
#    'properties': {'species': 'Fringilla_coelebs',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Cold summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [44.7233367787, 41.7166793331]},
#    'properties': {'species': 'Fringilla_coelebs',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.7256559829, 41.714976633]},
#    'properties': {'species': 'Fringilla_coelebs',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.059324, 39.183397]},
#    'properties': {'species': 'Fulica_americana',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8053954379, 28.3047061426]},
#    'properties': {'species': 'Fulica_americana',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8326906613, 28.5023491683]},
#    'properties': {'species': 'Fulica_americana',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.6519561126, 30.2197946159]},
#    'properties': {'species': 'Fulica_americana',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.751850704, 33.7947822153]},
#    'properties': {'species': 'Fulica_americana',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [75.5656122388, 20.979017916]},
#    'properties': {'species': 'Fulica_atra',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [75.5656122388, 20.979017916]},
#    'properties': {'species': 'Fulica_atra',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [75.5656122388, 20.979017916]},
#    'properties': {'species': 'Fulica_atra',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [75.5656122388, 20.979017916]},
#    'properties': {'species': 'Fulica_atra',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [120.5150735, 22.719575]},
#    'properties': {'species': 'Fulica_atra',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.833694, 33.767551]},
#    'properties': {'species': 'Haemorhous_mexicanus',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Hot'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.9394108738, 39.8747593882]},
#    'properties': {'species': 'Haemorhous_mexicanus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.8136966667, 34.2196366667]},
#    'properties': {'species': 'Haemorhous_mexicanus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.6818764375, 35.0820660411]},
#    'properties': {'species': 'Haemorhous_mexicanus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-88.177933, 42.394944]},
#    'properties': {'species': 'Haemorhous_mexicanus',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.3155059814, 40.1037406921]},
#    'properties': {'species': 'Haliaeetus_leucocephalus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9518662802, 42.6077182673]},
#    'properties': {'species': 'Haliaeetus_leucocephalus',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.3575066823, 28.6945560402]},
#    'properties': {'species': 'Haliaeetus_leucocephalus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.2495226142, 38.4049937785]},
#    'properties': {'species': 'Haliaeetus_leucocephalus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-70.55226778, 46.9889708301]},
#    'properties': {'species': 'Haliaeetus_leucocephalus',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [114.0826320544, 22.4359506122]},
#    'properties': {'species': 'Hirundo_rustica',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [13.7578938658, 46.5685407398]},
#    'properties': {'species': 'Hirundo_rustica',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [114.0696129575, 22.4950110665]},
#    'properties': {'species': 'Hirundo_rustica',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [15.3041493204, 50.905271877]},
#    'properties': {'species': 'Hirundo_rustica',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [14.3208259201, 53.8604184618]},
#    'properties': {'species': 'Hirundo_rustica',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-93.4197458725, 45.2895563332]},
#    'properties': {'species': 'Junco_hyemalis',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.4588384923, 38.578009045]},
#    'properties': {'species': 'Junco_hyemalis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.0243388333, 40.8950916667]},
#    'properties': {'species': 'Junco_hyemalis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.0748467936, 42.2647362091]},
#    'properties': {'species': 'Junco_hyemalis',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.6645050807, 33.1295482932]},
#    'properties': {'species': 'Junco_hyemalis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.3089770683, 27.8738871591]},
#    'properties': {'species': 'Larus_delawarensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-119.1979535777, 46.2320781312]},
#    'properties': {'species': 'Larus_delawarensis',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.7870310481, 28.2523527982]},
#    'properties': {'species': 'Larus_delawarensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.3801624591, 33.1893024467]},
#    'properties': {'species': 'Larus_delawarensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.1265220121, 29.4797458039]},
#    'properties': {'species': 'Larus_delawarensis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-86.1747133333, 42.496955]},
#    'properties': {'species': 'Meleagris_gallopavo',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8039469999, 28.309043951]},
#    'properties': {'species': 'Meleagris_gallopavo',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-99.8206994166, 24.9955725356]},
#    'properties': {'species': 'Meleagris_gallopavo',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-73.3426988, 45.5924997]},
#    'properties': {'species': 'Meleagris_gallopavo',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-123.2285916667, 43.9386633333]},
#    'properties': {'species': 'Meleagris_gallopavo',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.5211614577, 40.8553770815]},
#    'properties': {'species': 'Melospiza_melodia',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-102.189643594, 31.4075596253]},
#    'properties': {'species': 'Melospiza_melodia',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-73.7499466667, 40.65667]},
#    'properties': {'species': 'Melospiza_melodia',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.8875846904, 40.9674693036]},
#    'properties': {'species': 'Melospiza_melodia',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.8875846904, 40.9674693036]},
#    'properties': {'species': 'Melospiza_melodia',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.2269415066, 18.3347896838]},
#    'properties': {'species': 'Mimus_polyglottos',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Rainforest',
#     'climate_var3': nan}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-95.7655343, 29.8066414]},
#    'properties': {'species': 'Mimus_polyglottos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-74.0133138833, 40.7170916667]},
#    'properties': {'species': 'Mimus_polyglottos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.7466286864, 33.7959564677]},
#    'properties': {'species': 'Mimus_polyglottos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.00733, 39.216]},
#    'properties': {'species': 'Mimus_polyglottos',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [75.5656122388, 20.979017916]},
#    'properties': {'species': 'Motacilla_alba',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-0.2838494399, 50.927798773]},
#    'properties': {'species': 'Motacilla_alba',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [120.6810201332, 30.5091050732]},
#    'properties': {'species': 'Motacilla_alba',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [127.1176533333, 37.5188633333]},
#    'properties': {'species': 'Motacilla_alba',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [33.9776310325, 38.3251308627]},
#    'properties': {'species': 'Motacilla_alba',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.8080838769, 29.5032209614]},
#    'properties': {'species': 'Nannopterum_auritum',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.8081901583, 29.5017599287]},
#    'properties': {'species': 'Nannopterum_auritum',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-70.5489562766, 46.9830020584]},
#    'properties': {'species': 'Nannopterum_auritum',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-87.3207566667, 21.5177866667]},
#    'properties': {'species': 'Nannopterum_auritum',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1055626421, 38.9518711291]},
#    'properties': {'species': 'Nannopterum_auritum',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [114.2644666667, 22.3082633333]},
#    'properties': {'species': 'Nycticorax_nycticorax',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [121.3963166667, 23.1869416667]},
#    'properties': {'species': 'Nycticorax_nycticorax',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-58.44516, -34.6811316]},
#    'properties': {'species': 'Nycticorax_nycticorax',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [81.2648258, 6.2906436]},
#    'properties': {'species': 'Nycticorax_nycticorax',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [100.32841633, 6.18431671]},
#    'properties': {'species': 'Nycticorax_nycticorax',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Monsoon',
#     'climate_var3': nan}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.3374986275, 27.8653147797]},
#    'properties': {'species': 'Pandion_haliaetus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.3385500535, 27.8647267197]},
#    'properties': {'species': 'Pandion_haliaetus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.9840766713, 28.1298820349]},
#    'properties': {'species': 'Pandion_haliaetus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.9841972309, 28.1298284965]},
#    'properties': {'species': 'Pandion_haliaetus',
#     'climate_var1': 'Temperate',
# ...
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [30.4080983251, 50.4782576214]},
#    'properties': {'species': 'Parus_major',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [10.7934534353, 48.0255685854]},
#    'properties': {'species': 'Passer_domesticus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [75.5656122388, 20.979017916]},
#    'properties': {'species': 'Passer_domesticus',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-75.17173, 39.9588133333]},
#    'properties': {'species': 'Passer_domesticus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-73.7676101, 41.325871411]},
#    'properties': {'species': 'Passer_domesticus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [2.204199919, 41.4241585215]},
#    'properties': {'species': 'Passer_domesticus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-113.5610864885, 53.4978503045]},
#    'properties': {'species': 'Poecile_atricapillus',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.7084445555, 41.2852577592]},
#    'properties': {'species': 'Poecile_atricapillus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-73.4374973, 45.6810341]},
#    'properties': {'species': 'Poecile_atricapillus',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8705729276, 45.5916117576]},
#    'properties': {'species': 'Poecile_atricapillus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8363207584, 45.5467110037]},
#    'properties': {'species': 'Poecile_atricapillus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.1724383333, 27.6741783333]},
#    'properties': {'species': 'Quiscalus_mexicanus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.4127124997, 31.0407149997]},
#    'properties': {'species': 'Quiscalus_mexicanus',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-87.3326849, 20.3655155]},
#    'properties': {'species': 'Quiscalus_mexicanus',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.085539822, 11.4326904073]},
#    'properties': {'species': 'Quiscalus_mexicanus',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Savannah',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-114.9113234526, 32.0405742644]},
#    'properties': {'species': 'Quiscalus_mexicanus',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Desert',
#     'climate_var3': 'Hot'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8232860276, 32.9893520828]},
#    'properties': {'species': 'Setophaga_coronata',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.3027310744, 29.0212163831]},
#    'properties': {'species': 'Setophaga_coronata',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8053269564, 28.3046680398]},
#    'properties': {'species': 'Setophaga_coronata',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.1987699941, 28.6862485209]},
#    'properties': {'species': 'Setophaga_coronata',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-95.7655343, 29.8066414]},
#    'properties': {'species': 'Setophaga_coronata',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-92.5008677, 16.5711089083]},
#    'properties': {'species': 'Sialia_sialis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-93.7987308204, 32.6311047642]},
#    'properties': {'species': 'Sialia_sialis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.0672791574, 40.3287025619]},
#    'properties': {'species': 'Sialia_sialis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.2694855728, 41.3756828449]},
#    'properties': {'species': 'Sialia_sialis',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.6818294988, 35.0820784476]},
#    'properties': {'species': 'Sialia_sialis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.1940916667, 42.4908583333]},
#    'properties': {'species': 'Spinus_tristis',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-69.8656437829, 47.5687337591]},
#    'properties': {'species': 'Spinus_tristis',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.8857383333, 37.23907]},
#    'properties': {'species': 'Spinus_tristis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.6818294988, 35.0820784476]},
#    'properties': {'species': 'Spinus_tristis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-98.4772484043, 29.453884213]},
#    'properties': {'species': 'Spinus_tristis',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [3.8690167328, 50.4541794527]},
#    'properties': {'species': 'Streptopelia_decaocto',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-3.0078436062, 53.352979253]},
#    'properties': {'species': 'Streptopelia_decaocto',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [2.85837, 42.2242666667]},
#    'properties': {'species': 'Streptopelia_decaocto',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [11.8714486764, 42.4185465482]},
#    'properties': {'species': 'Streptopelia_decaocto',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [39.5913930969, 52.6183568558]},
#    'properties': {'species': 'Streptopelia_decaocto',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [3.312526, 43.4989844997]},
#    'properties': {'species': 'Sturnus_vulgaris',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-74.5880618691, 40.8735811542]},
#    'properties': {'species': 'Sturnus_vulgaris',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-87.6001782, 37.9777351]},
#    'properties': {'species': 'Sturnus_vulgaris',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [126.24524, 37.7950483333]},
#    'properties': {'species': 'Sturnus_vulgaris',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [126.2464983333, 37.7984316667]},
#    'properties': {'species': 'Sturnus_vulgaris',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry winter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [9.0553721667, 48.5234333333]},
#    'properties': {'species': 'Turdus_merula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-6.262083, 53.633894]},
#    'properties': {'species': 'Turdus_merula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [30.4592664912, 59.9231400241]},
#    'properties': {'species': 'Turdus_merula',
#     'climate_var1': 'Boreal',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-3.8251133333, 53.2803]},
#    'properties': {'species': 'Turdus_merula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-1.8969324833, 50.7454848667]},
#    'properties': {'species': 'Turdus_merula',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Warm summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8232545117, 32.9893570613]},
#    'properties': {'species': 'Turdus_migratorius',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-96.8043231693, 28.309093421]},
#    'properties': {'species': 'Turdus_migratorius',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.2540851215, 26.7295667877]},
#    'properties': {'species': 'Turdus_migratorius',
#     'climate_var1': 'Tropical',
#     'climate_var2': 'Rainforest',
#     'climate_var3': nan}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.463431505, 39.0699896219]},
#    'properties': {'species': 'Turdus_migratorius',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-95.7655343, 29.8066414]},
#    'properties': {'species': 'Turdus_migratorius',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-85.3699999, 35.0711953]},
#    'properties': {'species': 'Zenaida_macroura',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-74.0292978592, 40.6254768434]},
#    'properties': {'species': 'Zenaida_macroura',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-87.6063095, 37.9777167]},
#    'properties': {'species': 'Zenaida_macroura',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-84.5337351412, 39.1640386261]},
#    'properties': {'species': 'Zenaida_macroura',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-95.7655343, 29.8066414]},
#    'properties': {'species': 'Zenaida_macroura',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Without dry season'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-102.0202363135, 31.3995293513]},
#    'properties': {'species': 'Zonotrichia_leucophrys',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-102.0206758405, 31.3994998125]},
#    'properties': {'species': 'Zonotrichia_leucophrys',
#     'climate_var1': 'Arid',
#     'climate_var2': 'Steppe',
#     'climate_var3': 'Cold'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.056623, 39.187159]},
#    'properties': {'species': 'Zonotrichia_leucophrys',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.7570608723, 33.799701071]},
#    'properties': {'species': 'Zonotrichia_leucophrys',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.0587852612, 33.7097485215]},
#    'properties': {'species': 'Zonotrichia_leucophrys',
#     'climate_var1': 'Temperate',
#     'climate_var2': 'Hot summer',
#     'climate_var3': 'Dry summer'}}]}

# %% [markdown]
# ## Koppen Geiger en geojson

# %%
import geopandas as gpd

# Charger le shapefile
shapefile_path = "climates.shp"  # Remplace par le bon chemin
gdf = gpd.read_file(shapefile_path)

# Convertir en GeoJSON
geojson_path = "koppen_geiger.geojson"
gdf.to_file(geojson_path, driver="GeoJSON")

print(f"Fichier GeoJSON sauvegardé sous {geojson_path}")
# Out:
# C:\Users\diora\AppData\Roaming\Python\Python312\site-packages\pyogrio\geopandas.py:662: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
# Fichier GeoJSON sauvegardé sous koppen_geiger.geojson
